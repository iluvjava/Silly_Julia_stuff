# %%
using Plots

# %% [markdown]
# ### Intro
#
# Reference for Plots Library [here](http://docs.juliaplots.org/latest/tutorial/#Basic-Plotting:-Line-Plots)

# %% [markdown]
# ### Basic Plots

# %%
plot(rand(10))
plot!(rand(10))
